# %%
'''
Challenge 2
Author- Parthivi Jain
Team Name- AGRI_AI
Team Leader- Parthivi Jain (Email id- i22ma014@amhd.svnit.ac.in) (Integrated Masters of Science in Mathematics, SVNIT, Surat)
Team Member- Surya Pratap Yadav (Email id- i22ma044@amhd.svnit.ac.in) (Integrated Masters of Science in Mathematics, SVNIT, Surat)
Leaderboard Rank- 30
'''
# Out:
# '\nChallenge 2\nAuthor- Parthivi Jain\nTeam Name- AGRI_AI\nTeam Leader- Parthivi Jain (Email id- i22ma014@amhd.svnit.ac.in) (Integrated Masters of Science in Mathematics, SVNIT, Surat)\nTeam Member- Surya Pratap Yadav (Email id- i22ma044@amhd.svnit.ac.in) (Integrated Masters of Science in Mathematics, SVNIT, Surat)\nLeaderboard Rank- 30\n'
